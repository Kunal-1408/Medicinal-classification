# %%
import tensorflow as tf
import os
# Out:
# 2023-09-15 14:40:48.948365: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-15 14:40:49.587039: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print(tf.config.list_physical_devices('GPU'))
tf.debugging.set_log_device_placement(True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-09-15 14:40:50.870816: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:40:50.906650: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:40:50.906721: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
from sklearn.model_selection import train_test_split
import shutil
import random

# %%
dataset_directory = 'dataset'

# %%
output_directory = 'final1'

# %%
train_dir = os.path.join(output_directory, 'train')
test_dir = os.path.join(output_directory, 'test')
val_dir=os.path.join(output_directory, 'val')
# Create directories for train, validation, and test sets
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# %%
classes = os.listdir(dataset_directory)

# Split dataset into training, validation, and test sets for each class
for class_name in classes:
    class_dir = os.path.join(dataset_directory, class_name)
    image_files = os.listdir(class_dir)
    random.shuffle(image_files)
    
    # Split the images for each class
    train_files, temp_files = train_test_split(image_files, test_size=0.3, random_state=42)
    val_files, test_files = train_test_split(temp_files, test_size=0.33, random_state=42)
    
    # Create directories for each class in train, validation, and test sets
    train_class_dir = os.path.join(train_dir, class_name)
    val_class_dir = os.path.join(val_dir, class_name)
    test_class_dir = os.path.join(test_dir, class_name)
    
    os.makedirs(train_class_dir, exist_ok=True)
    os.makedirs(val_class_dir, exist_ok=True)
    os.makedirs(test_class_dir, exist_ok=True)
    
    # Move images to their respective directories
    for file in train_files:
        src = os.path.join(class_dir, file)
        dst = os.path.join(train_class_dir, file)
        shutil.copy(src, dst)
        
    for file in val_files:
        src = os.path.join(class_dir, file)
        dst = os.path.join(val_class_dir, file)
        shutil.copy(src, dst)
        
    for file in test_files:
        src = os.path.join(class_dir, file)
        dst = os.path.join(test_class_dir, file)
        shutil.copy(src, dst)


print("Dataset split into train and test sets successfully.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 31
#      29     src = os.path.join(class_dir, file)
#      30     dst = os.path.join(val_class_dir, file)
# ---> 31     shutil.copy(src, dst)
#      33 for file in test_files:
#      34     src = os.path.join(class_dir, file)
#
# File ~/miniconda3/envs/tf/lib/python3.9/shutil.py:428, in copy(src, dst, follow_symlinks)
#     426     dst = os.path.join(dst, os.path.basename(src))
#     427 copyfile(src, dst, follow_symlinks=follow_symlinks)
# --> 428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File ~/miniconda3/envs/tf/lib/python3.9/shutil.py:316, in copymode(src, dst, follow_symlinks)
#     313 else:
#     314     stat_func, chmod_func = _stat, os.chmod
# --> 316 st = stat_func(src)
#     317 chmod_func(dst, stat.S_IMODE(st.st_mode))
#
# File ~/miniconda3/envs/tf/lib/python3.9/shutil.py:229, in _stat(fn)
#     228 def _stat(fn):
# --> 229     return fn.stat() if isinstance(fn, os.DirEntry) else os.stat(fn)
#
# KeyboardInterrupt:

# %%
from keras.applications import ResNet50
conv_base = ResNet50(weights='imagenet',
include_top=False)

# %%
conv_base.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv1_pad (ZeroPadding2D)   (None, None, None, 3)        0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, None, None, 64)       9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, None, None, 64)       256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, None, None, 64)       0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, None, None, 64)       0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None
168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, None, None, 1024)     4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, None, None, 1024)     0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, None, None, 1024)     0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, None, None, 512)      524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, None, None, 512)      0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, None, None, 512)      2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, None, None, 512)      0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, None, None, 2048)     2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, None, None, 2048)     1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, None, None, 2048)     0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, None, None, 2048)     0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, None, None, 512)      1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, None, None, 512)      0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, None, None, 512)      2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, None, None, 512)      0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, None, None, 2048)     1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, None, None, 2048)     0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, None, None, 2048)     0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, None, None, 512)      1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, None, None, 512)      0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, None, None, 512)      2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, None, None, 512)      2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, None, None, 512)      0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, None, None, 2048)     1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, None, None, 2048)     8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, None, None, 2048)     0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, None, None, 2048)     0         ['conv5_block3_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
base_dir = 'final1'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
datagen = ImageDataGenerator(rescale=1./255)
batch_size = 20

# %%
def extract_features(directory, sample_count):
    features = np.zeros(shape=(sample_count, 4, 4, 512))
    labels = np.zeros(shape=(sample_count))
    generator = datagen.flow_from_directory(
    directory,
    target_size=(150, 150),
    batch_size=batch_size,
    class_mode='binary')
    i = 0
    for inputs_batch, labels_batch in generator:
        features_batch = conv_base.predict(inputs_batch)
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = labels_batch
        i += 1
        if i * batch_size >= sample_count:
            break
    return features, labels

# %%
train_features, train_labels = extract_features(train_dir, 1000)
validation_features, validation_labels = extract_features(validation_dir, 500)
test_features, test_labels = extract_features(test_dir, 500)
# Out:
# Found 4835 images belonging to 80 classes.
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RangeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ZipDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# k:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# value: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# count: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# MapDataset: (MapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# FlatMapDataset: (FlatMapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# components_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# count: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__datasets_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# input__datasets_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# ZipDataset: (ZipDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# num__parallel__calls: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# ParallelMapDatasetV2: (ParallelMapDatasetV2): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# buffer__size: (_Arg): /job:localhost/replica:0/tasExecuting op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AnonymousIteratorV3 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.243041: I tensorflow/core/common_runtime/placer.cc:114] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.243125: I tensorflow/core/common_runtime/placer.cc:114] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.245722: I tensorflow/core/common_runtime/placer.cc:114] resource: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.245788: I tensorflow/core/common_runtime/placer.cc:114] value: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.245820: I tensorflow/core/common_runtime/placer.cc:114] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.257287: I tensorflow/core/common_runtime/placer.cc:114] start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.257354: I tensorflow/core/common_runtime/placer.cc:114] stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.257364: I tensorflow/core/common_runtime/placer.cc:114] step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.257391: I tensorflow/core/common_runtime/placer.cc:114] RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.257400: I tensorflow/core/common_runtime/placer.cc:114] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.261223: I tensorflow/core/common_runtime/placer.cc:114] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.261269: I tensorflow/core/common_runtime/placer.cc:114] count: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.261279: I tensorflow/core/common_runtime/placer.cc:114] RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29
handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.335570: I tensorflow/core/common_runtime/placer.cc:114] AnonymousIteratorV3: (AnonymousIteratorV3): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.336952: I tensorflow/core/common_runtime/placer.cc:114] dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.336989: I tensorflow/core/common_runtime/placer.cc:114] iterator: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.336998: I tensorflow/core/common_runtime/placer.cc:114] MakeIterator: (MakeIterator): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.342574: I tensorflow/core/common_runtime/placer.cc:114] args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.342637: I tensorflow/core/common_runtime/placer.cc:114] range: (Range): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.342645: I tensorflow/core/common_runtime/placer.cc:114] Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.342649: I tensorflow/core/common_runtime/placer.cc:114] identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.342652: I tensorflow/core/common_runtime/placer.cc:114] range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.342656: I tensorflow/core/common_runtime/placer.cc:114] range/limit: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.342659: I tensorflow/core/common_runtime/placer.cc:114] range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358754: I tensorflow/core/common_runtime/placer.cc:114] args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358818: I tensorflow/core/common_runtime/placer.cc:114] Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358828: I tensorflow/core/common_runtime/placer.cc:114] Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358834: I tensorflow/core/common_runtime/placer.cc:114] TensorSliceDataset: (TensorSliceDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358841: I tensorflow/core/common_runtime/placer.cc:114] Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358846: I tensorflow/core/common_runtime/placer.cc:114] TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358849: I tensorflow/core/common_runtime/placer.cc:114] ConcatenateDataset: (ConcatenateDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358853: I tensorflow/core/common_runtime/placer.cc:114] NoOp: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358857: I tensorflow/core/common_runtime/placer.cc:114] Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358860: I tensorflow/core/common_runtime/placer.cc:114] identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358863: I tensorflow/core/common_runtime/placer.cc:114] Slice/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358867: I tensorflow/core/common_runtime/placer.cc:114] Slice/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358870: I tensorflow/core/common_runtime/placer.cc:114] Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358874: I tensorflow/core/common_runtime/placer.cc:114] Slice_1/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.358877: I tensorflow/core/common_runtime/placer.cc:114] Slice_1/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.363896: I tensorflow/core/common_runtime/placer.cc:114] args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.363947: I tensorflow/core/common_runtime/placer.cc:114] args_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.363958: I tensorflow/core/common_runtime/placer.cc:114] GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.363962: I tensorflow/core/common_runtime/placer.cc:114] Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.363965: I tensorflow/core/common_runtime/placer.cc:114] identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.363969: I tensorflow/core/common_runtime/placer.cc:114] GatherV2/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.815595: I tensorflow/core/common_runtime/placer.cc:114] iterator: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-09-15 14:41:29.815717: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv1_conv_conv2d_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815727: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv1_conv_biasadd_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815732: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv1_bn_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815736: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv1_bn_readvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815739: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv1_bn_fusedbatchnormv3_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815743: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv1_bn_fusedbatchnormv3_readvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815746: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_1_conv_conv2d_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815750: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_1_conv_biasadd_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815754: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_1_bn_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815795: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_1_bn_readvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815813: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_1_bn_fusedbatchnormv3_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815823: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_1_bn_fusedbatchnormv3_readvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815832: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_2_conv_conv2d_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815839: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_2_conv_biasadd_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815845: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_2_bn_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815851: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_2_bn_readvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815857: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_2_bn_fusedbatchnormv3_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815861: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_2_bn_fusedbatchnormv3_readvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815865: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_block1_3_conv_conv2d_readvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2023-09-15 14:41:29.815869: I tensorflow/core/common_runtime/placer.cc:114] resnet50_conv2_
/job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_2_relu/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_0_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_3_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_add/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block1_out/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_1_relu/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_2_relu/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_3_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_add/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block2_out/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_1_relu/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_2_relu/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_conv/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_conv/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_conv/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_conv/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_bn/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_bn/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_bn/FusedBatchNormV3/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_bn/FusedBatchNormV3/ReadVariableOp_1: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_3_bn/FusedBatchNormV3: (FusedBatchNormV3): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_add/add: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv5_block3_out/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# AssignAddVariableOp: (AssignAddVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# NoOp: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# Identity: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/conv1_pad/Pad/paddings: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# resnet50/pool1_pad/Pad/paddings: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# Const: (Const): /joExecuting op __inference_predict_function_5039 in device /job:localhost/replica:0/task:0/device:GPU:0

# %%
from keras import models
from keras import layers
from keras import optimizers
# Out:
# 2023-09-15 14:54:04.550540: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-15 14:54:05.446623: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_dim=4 * 4 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# 2023-09-15 14:54:07.274585: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:07.327078: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:07.327177: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:07.330112: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:07.330202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:07.330246: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:08.232928: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:08.233184: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:08.233199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-09-15 14:54:08.233260: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 14:54:08.233298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2072 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_dim=4 * 4 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer=optimizers.RMSprop(learning_rate=2e-5),
loss='binary_crossentropy',
metrics=['acc'])

# %%
history = model.fit(train_features, train_labels,
epochs=30,
batch_size=20,
validation_data=(validation_features, validation_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 history = model.fit(train_features, train_labels,
#       2 epochs=30,
#       3 batch_size=20,
#       4 validation_data=(validation_features, validation_labels))
#
# NameError: name 'train_features' is not defined

# %%
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
